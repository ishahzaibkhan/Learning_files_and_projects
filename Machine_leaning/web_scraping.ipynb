# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# The kernel failed to start as the Python Environment 'NLP (Python 3.11.9)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
